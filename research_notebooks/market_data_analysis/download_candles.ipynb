# %%
# This is necessary to recognize the modules
import os
import sys
from decimal import Decimal
import warnings

warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.data_sources.clob import CLOBDataSource

# Get trading rules and candles
clob = CLOBDataSource()

# %%
# Constants
CONNECTOR_NAME = "binance_perpetual"
INTERVALS = ["1m", "5m", "15m", "30m" ]
trading_pairs = ["BTC-USDT", "WLD-USDT", "ETH-USDT", "XRP-USDT", "BNB-USDT", "SOL-USDT"]

DAYS = 700

# %%
# Download Data
BATCH_CANDLES_REQUEST = 1
SLEEP_REQUEST = 1

all_candles = {
    interval: await clob.get_candles_batch_last_days(CONNECTOR_NAME, trading_pairs, interval, DAYS, BATCH_CANDLES_REQUEST,
                                                  SLEEP_REQUEST) for interval in INTERVALS
}
clob.dump_candles_cache(root_path)
# Out:
# Batch 1/7
# Start: 0, End: 1
# 2025-04-12 17:20:32,724 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x77806c7234c0>
# 2025-04-12 17:20:32,725 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x77806fef8d00>, 19026.717664118)])']
# connector: <aiohttp.connector.TCPConnector object at 0x77806c721270>
# Batch 2/7
# Start: 1, End: 2
# 2025-04-12 17:25:13,811 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x77806c6f6b90>
# 2025-04-12 17:25:13,812 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x77806c48dba0>, 19307.81544222)])']
# connector: <aiohttp.connector.TCPConnector object at 0x77806c6f4130>
# Batch 3/7
# Start: 2, End: 3
# 2025-04-12 17:30:40,408 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x77806c441450>
# 2025-04-12 17:30:40,409 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x77806c48dd20>, 19634.380502635)])']
# connector: <aiohttp.connector.TCPConnector object at 0x77806c441e10>
# Batch 4/7
# Start: 3, End: 4
# 2025-04-12 17:36:09,594 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x77806c723d90>
# 2025-04-12 17:36:09,595 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x77806c48f3a0>, 19963.581964249)])']
# connector: <aiohttp.connector.TCPConnector object at 0x77806c723790>
# Batch 5/7
# Start: 4, End: 5
# 2025-04-12 17:41:41,899 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x77806c4415a0>
# 2025-04-12 17:41:41,900 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x77806c48dd20>, 20295.866330494)])']
# connector: <aiohttp.connector.TCPConnector object at 0x77806c4417b0>
# Batch 6/7
# Start: 5, End: 6
# 2025-04-12 17:47:17,172 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x77806c6f7610>
# 2025-04-12 17:47:17,174 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x77806c48f940>, 20631.144579128)])']
# connector: <aiohttp.connector.TCPConnector object at 0x77806c6f6b60>
# Batch 7/7
# Start: 6, End: 7
