# %%
# This is necessary to recognize the modules
import os
import sys
from decimal import Decimal
import warnings

warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.data_sources.clob import CLOBDataSource

# Get trading rules and candles
clob = CLOBDataSource()

# %%
# Constants
CONNECTOR_NAME = "binance_perpetual"
INTERVALS = ["1m" ]
# INTERVALS = [ "5m"]
# INTERVALS = ["15m"]
# INTERVALS = ["30m"]
trading_pairs = ["BTC-USDT", "WLD-USDT", "ETH-USDT", "XRP-USDT", "BNB-USDT", "SOL-USDT"]
# trading_pairs = ["BTC-USDT"]
# trading_pairs = ["WLD-USDT"]
# trading_pairs = ["ETH-USDT",]
# trading_pairs = ["XRP-USDT",]
# trading_pairs = ["BNB-USDT",]
# trading_pairs = ["SOL-USDT"]


DAYS = 700

# %%
# Download Data
BATCH_CANDLES_REQUEST = 10
SLEEP_REQUEST = 2

all_candles = {
    interval: await clob.get_candles_batch_last_days(CONNECTOR_NAME, trading_pairs, interval, DAYS, BATCH_CANDLES_REQUEST,
                                                  SLEEP_REQUEST) for interval in INTERVALS
}
clob.dump_candles_cache(root_path)
# Out:
# Batch 1/1
# Start: 0, End: 10
# 2025-04-12 17:00:22,736 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x77806c723820>
# 2025-04-12 17:00:22,738 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x77806c681840>, 17817.041694231)])']
# connector: <aiohttp.connector.TCPConnector object at 0x77806c720910>
